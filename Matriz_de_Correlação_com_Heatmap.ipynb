# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
import random

# Dados iniciais (participantes 1 e 2)
data = [
    [1, 'Experimental', 'Swing', 120, 1, 4, 3, 2, 4, 5, 4, 2, 1, 4, 4, 4, 1, 5, 35, 'Feminino', 'Superior', 'Alta', 'Sim', 'Nenhuma', 'Heterossexual'],
    [1, 'Experimental', 'Swing', 120, 2, 5, 4, 1, 5, 5, 5, 1, 1, 5, 5, 5, 1, 5, 35, 'Feminino', 'Superior', 'Alta', 'Sim', 'Nenhuma', 'Heterossexual'],
    [1, 'Experimental', 'Swing', 120, 3, 5, 5, 1, 5, 5, 5, 1, 1, 5, 5, 5, 1, 5, 35, 'Feminino', 'Superior', 'Alta', 'Sim', 'Nenhuma', 'Heterossexual'],
    [2, 'Controle', 'Swing', 80, 1, 3, 2, 3, 3, 4, 3, 3, 2, 3, 3, 3, 2, 4, 42, 'Masculino', 'Superior', 'Média', 'Não', 'Catolicismo', 'Heterossexual'],
    [2, 'Controle', 'Swing', 80, 2, 3, 2, 3, 3, 4, 3, 3, 2, 3, 3, 3, 2, 4, 42, 'Masculino', 'Superior', 'Média', 'Não', 'Catolicismo', 'Heterossexual']
]

# Visualização com cores vibrantes usando heatmap
plt.figure(figsize=(14, 10))
sns.set_theme(style="white")  # Fundo branco para melhor contraste

# Seleciona as colunas numéricas para o heatmap
numeric_df = df.select_dtypes(include=np.number)

# Calcula a matriz de correlação
corr_matrix = numeric_df.corr()

# Cria o heatmap com a paleta de cores "viridis"
sns.heatmap(corr_matrix, annot=True, cmap="viridis", fmt=".2f", linewidths=.5, annot_kws={"size": 8})
plt.title('Matriz de Correlação com Heatmap', fontsize=16)
plt.show()


# Salva o DataFrame em CSV
df.to_csv('synthetic_data_with_demographics.csv', index=False)
