# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io



# Dados sintéticos em CSV embutidos no código
data_csv = """participante,tipo_relacionamento,tempo_relacionamento_meses,compersao,paresia,ciume,satisfacao_relacional,comunicacao,autoestima,pensamentos_intrusivos,ansiedade_social,suporte_social,empatia,regulacao_emocional,comportamentos_evitativos,flexibilidade_cognitiva
1,Swing,120,4,3,2,4,5,4,2,1,4,4,4,1,5
2,Swing,80,3,2,3,3,4,3,3,2,3,3,3,2,4
3,Swing,50,2,1,4,2,3,2,4,3,2,2,2,3,3
4,Swing,100,5,4,1,5,5,5,1,1,5,5,5,1,5
5,Swing,60,3,3,2,4,4,4,2,2,4,4,4,2,4
6,Swing,72,2,2,3,2,2,3,4,2,3,3,2,3,2
7,Swing,95,4,4,2,4,5,4,2,1,5,4,4,1,4
8,Swing,48,1,2,5,1,2,1,5,4,1,1,1,4,2
9,Swing,110,5,5,1,5,5,5,1,1,5,5,5,1,5
10,Swing,65,3,3,3,4,4,3,3,2,4,3,4,2,3
11,Swing,88,4,3,2,5,4,4,2,1,4,4,5,1,4
12,Swing,55,2,2,4,3,3,2,3,3,3,2,3,2,3
13,Swing,105,5,4,1,5,5,5,1,1,5,5,5,1,5
14,Swing,70,3,2,2,4,4,3,2,2,3,4,4,2,4
15,Swing,45,1,1,5,2,2,1,4,4,2,1,2,4,1
16,Swing,92,4,4,1,5,4,5,1,1,4,5,4,1,5
17,Swing,68,3,3,2,4,3,4,2,2,4,4,3,2,4
18,Swing,52,2,1,4,2,3,2,4,3,2,2,2,3,2
19,Swing,115,5,5,1,5,5,5,1,1,5,5,5,1,5
20,Swing,75,4,3,2,4,4,4,2,1,4,4,4,1,4
21,Swing,40,1,2,4,1,2,2,5,3,1,2,1,3,2
22,Swing,98,5,4,1,5,5,5,1,1,5,5,5,1,5
23,Swing,62,3,2,3,3,4,3,3,2,3,3,3,2,3
24,Swing,85,4,3,2,4,5,4,2,1,4,4,4,1,5
25,Swing,58,2,2,4,3,3,2,3,3,3,3,3,3,3
26,Swing,108,5,5,1,5,5,5,1,1,5,5,5,1,5
27,Swing,78,4,3,2,4,4,4,2,1,4,4,4,1,4
28,Swing,42,2,1,5,1,2,1,5,4,1,1,1,4,2
29,Swing,102,5,4,1,5,5,5,1,1,5,5,5,1,5
30,Swing,66,3,3,3,4,4,3,2,2,4,3,4,2,4
31,Swing,90,4,4,2,5,4,4,1,1,5,4,5,1,4
32,Swing,53,2,1,4,3,3,2,4,3,2,2,2,3,3
33,Swing,118,5,5,1,5,5,5,1,1,5,5,5,1,5
34,Swing,82,4,3,2,4,5,4,2,1,4,4,4,1,5
35,Swing,47,1,2,5,2,2,1,4,4,2,1,2,4,1
36,Swing,96,4,4,1,5,4,5,1,1,4,5,4,1,5
37,Swing,71,3,2,2,4,4,3,2,2,3,4,4,2,4
38,Swing,57,2,1,4,2,3,2,4,3,2,2,2,3,2
39,Swing,112,5,5,1,5,5,5,1,1,5,5,5,1,5
40,Swing,79,4,3,2,4,4,4,2,1,4,4,4,1,4"""



# Criando o DataFrame
df = pd.read_csv(io.StringIO(data_csv))

# Calcula a matriz de correlação
corr_matrix = df[['compersao', 'paresia', 'ciume', 'satisfacao_relacional']].corr()

# Heatmap com cores divergentes e anotações
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1, center=0, fmt=".2f", linewidths=.5, annot_kws={"size": 10})
plt.title('Matriz de Correlação - Heatmap', fontsize=16)
plt.show()
