# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# Dados sintéticos em CSV embutidos no código
data_csv = """participante,tipo_relacionamento,tempo_relacionamento_meses,compersao,paresia,ciume,satisfacao_relacional,comunicacao,autoestima
1,Swing,120,4,3,2,4,5,4
2,Swing,80,3,2,3,3,4,3
3,Swing,50,2,1,4,2,3,2
4,Swing,100,5,4,1,5,5,5
5,Swing,60,3,3,2,4,4,4
6,Swing,130,4,5,1,5,5,4
7,Swing,90,2,2,3,3,3,3
8,Swing,70,3,1,4,2,2,2
9,Swing,110,5,5,1,5,4,5
10,Swing,100,4,4,2,4,5,4
11,Poliamor,120,5,5,2,5,5,5
12,Poliamor,100,4,4,3,4,4,4
13,Poliamor,80,3,3,4,3,3,3
14,Poliamor,60,2,2,5,2,2,2
15,Poliamor,110,5,4,2,4,5,4
16,Poliamor,90,4,3,3,3,4,3
17,Poliamor,70,3,2,4,2,3,2
18,Poliamor,130,5,5,1,5,5,5
19,Poliamor,50,2,1,5,1,1,1
20,Poliamor,100,4,4,2,4,4,4
21,Aberto,120,4,4,2,4,4,4
22,Aberto,80,3,3,3,3,3,3
23,Aberto,130,5,5,1,5,5,5
24,Aberto,100,4,2,3,4,5,2
25,Aberto,90,5,4,1,4,4,5
26,Aberto,110,3,3,4,3,3,3
27,Aberto,70,2,2,5,2,2,2
28,Aberto,60,1,1,5,1,1,1
29,Aberto,50,4,5,2,5,4,5
30,Aberto,100,5,3,1,4,5,3
31,Monogâmico,120,2,2,3,3,3,3
32,Monogâmico,80,1,1,4,2,2,2
33,Monogâmico,130,3,3,2,4,4,4
34,Monogâmico,100,2,4,3,3,5,4
35,Monogâmico,90,1,3,4,2,4,3
36,Monogâmico,110,2,5,2,4,3,5
37,Monogâmico,70,1,2,5,1,2,2
38,Monogâmico,60,3,1,4,3,1,1
39,Monogâmico,50,2,3,3,2,3,3
40,Monogâmico,100,1,4,4,1,4,4"""

# Criando o DataFrame
df = pd.read_csv(io.StringIO(data_csv))

# Visualização com Seaborn e cores vibrantes
plt.figure(figsize=(10, 6))
sns.set_palette("magma") # Paleta de cores "magma"

# Boxplot da satisfação relacional por tipo de relacionamento
sns.boxplot(x='tipo_relacionamento', y='satisfacao_relacional', data=df)
plt.title('Satisfação Relacional por Tipo de Relacionamento', fontsize=14)
plt.xticks(rotation=45, ha='right') # Rotaciona os rótulos do eixo x para melhor visualização
plt.tight_layout() # Ajusta o layout para evitar sobreposição de elementos
plt.show()


# Salvando o DataFrame em CSV
df.to_csv('dados_sinteticos.csv', index=False)

# Imprimindo o DataFrame
print(df)
# Out:
#     participante tipo_relacionamento  tempo_relacionamento_meses  compersao  \
# 0              1               Swing                         120          4
# 1              2               Swing                          80          3
# 2              3               Swing                          50          2
# 3              4               Swing                         100          5
# 4              5               Swing                          60          3
# 5              6               Swing                         130          4
# 6              7               Swing                          90          2
# 7              8               Swing                          70          3
# 8              9               Swing                         110          5
# 9             10               Swing                         100          4
# 10            11            Poliamor                         120          5
# ...
