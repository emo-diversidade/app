'Swing', 120, 2, 3, 2, 1, 4, 5, 4, 1, 1, 5, 3, 4, 1, 4], [1, 'Swing', 120, 3, 5, 5, 1, 4, 5, 5, 2, 2, 5, 5, 4, 1, 5], [1, 'Swing', 120, 1, 2, 2, 3, 2, 3, 4, 3, 3, 4, 2, 2, 2, 4], [1, 'Swing', 120, 2, 4, 3, 2, 5, 4, 5, 1, 1, 5, 3, 5, 2, 4], [1, 'Swing', 120, 2, 4, 3, 2, 5, 4, 5, 1, 1, 5, 4, 5, 2, 5], [1, 'Swing', 120, 2, 2, 3, 3, 4, 3, 2, 4, 1, 2, 3, 2, 1, 4], [1, 'Swing', 120, 3, 4, 3, 1, 5, 4, 5, 3, 2, 5, 3, 3, 2, 4], [1, 'Swing', 120, 2, 5, 3, 2, 5, 4, 5, 2, 2, 4, 4, 5, 1, 5], [1, 'Swing', 120, 1, 4, 1, 3, 2, 4, 3, 2, 3, 2, 3, 4, 3, 4], [1, 'Swing', 120, 2, 4, 3, 1, 3, 5, 5, 1, 1, 4, 4, 3, 1, 4], [1, 'Swing', 120, 3, 5, 3, 2, 5, 5, 4, 2, 2, 5, 5, 5, 2, 5], [1, 'Swing', 120, 1, 3, 3, 3, 3, 3, 2, 2, 2, 2, 3, 4, 3, 3]]
data.extend([
    [1, 'Swing', 120, 1, 4, 2, 4, 4, 4, 2, 4, 3, 2, 2, 4, 2, 4],
    [1, 'Swing', 120, 2, 3, 2, 1, 4, 5, 5, 1, 1, 4, 4, 4, 2, 5],
    [1, 'Swing', 120, 4, 5, 3, 2, 5, 5, 5, 1, 2, 4, 5, 5, 1, 4],
    [1, 'Swing', 120, 1, 3, 3, 4, 2, 4, 4, 4, 1, 4, 2, 2, 3, 5],
    [1, 'Swing', 120, 2, 4, 3, 3, 5, 4, 3, 1, 1, 4, 5, 4, 1, 4],
    [1, 'Swing', 120, 4, 5, 4, 1, 5, 5, 5, 2, 1, 5, 4, 5, 2, 4],
    [1, 'Swing', 120, 1, 3, 1, 3, 2, 5, 4, 3, 1, 3, 4, 3, 2, 3],
    [1, 'Swing', 120, 1, 5, 3, 2, 3, 5, 5, 3, 2, 5, 5, 3, 2, 5],
    [1, 'Swing', 120, 3, 4, 5, 1, 5, 5, 5, 1, 1, 5, 5, 4, 1, 5],
    [1, 'Swing', 120, 2, 2, 1, 4, 2, 5, 3, 2, 3, 2, 4, 2, 3, 4],
    [1, 'Swing', 120, 1, 3, 3, 1, 5, 5, 3, 3, 1, 5, 3, 5, 1, 5],
    [1, 'Swing', 120, 2, 5, 3, 2, 4, 5, 5, 1, 2, 5, 5, 5, 1, 5],
    [1, 'Swing', 120, 2, 2, 1, 4, 2, 3, 2, 2, 1, 4, 3, 2, 2, 3],
    [1, 'Swing', 120, 2, 5, 2, 3, 5, 5, 3, 1, 1, 5, 3, 5, 1, 5],
    [1, 'Swing', 120, 2, 5, 4, 1, 5, 5, 5, 1, 1, 5, 5, 4, 1, 5],
    [1, 'Swing', 120, 1, 2, 3, 2, 3, 5, 3, 4, 2, 3, 3, 4, 2, 5],
    [1, 'Swing', 120, 2, 3, 4, 3, 4, 5, 4, 3, 1, 5, 5, 5, 2, 4],
    [1, 'Swing', 120, 4, 5, 5, 1, 5, 5, 5, 2, 1, 4, 4, 4, 2, 5],
    [1, 'Swing', 120, 2, 3, 1, 2, 2, 4, 3, 3, 2, 2, 3, 2, 2, 5],
    [1, 'Swing', 120, 1, 5, 4, 1, 4, 5, 4, 3, 2, 3, 4, 5, 1, 5],
    [1, 'Swing', 120, 3, 5, 4, 2, 4, 5, 5, 1, 2, 5, 5, 4, 2, 5],
    [1, 'Swing', 120, 1, 2, 2, 2, 2, 3, 3, 3, 1, 4, 4, 3, 1, 4],
    [1, 'Swing', 120, 3, 5, 4, 1, 3, 5, 4, 1, 2, 5, 3, 4, 1, 5],
    [1, 'Swing', 120, 4, 5, 3, 1, 4, 5, 4, 2, 2, 5, 4, 4, 1, 4],
    [1, 'Swing', 120, 1, 4, 3, 2, 4, 4, 2, 3, 3, 2, 3, 3, 3, 4],
    [1, 'Swing', 120, 1, 5, 3, 1, 5, 5, 5, 3, 1, 4, 3, 3, 1, 5],
    [1, 'Swing', 120, 2, 4, 5, 1, 5, 5, 5, 1, 2, 5, 4, 5, 1, 5],
    [1, 'Swing', 120, 2, 2, 3, 2, 4, 3, 3, 2, 2, 4, 2, 2, 1, 4],
    [1, 'Swing', 120, 2, 3, 2, 1, 4, 5, 4, 1, 1, 5, 3, 4, 1, 4],
    [1, 'Swing', 120, 3, 5, 5, 1, 4, 5, 5, 2, 2, 5, 5, 4, 1, 5],
    [1, 'Swing', 120, 1, 2, 2, 3, 2, 3, 4, 3, 3, 4, 2, 2, 2, 4],
    [1, 'Swing', 120, 2, 4, 3, 2, 5, 4, 5, 1, 1, 5, 3, 5, 2, 4],
    [1, 'Swing', 120, 2, 4, 3, 2, 5, 4, 5, 1, 1, 5, 4, 5, 2, 5],
    [1, 'Swing', 120, 2, 2, 3, 3, 4, 3, 2, 4, 1, 2, 3, 2, 1, 4],
    [1, 'Swing', 120, 3, 4, 3, 1, 5, 4, 5, 3, 2, 5, 3, 3, 2, 4],
    [1, 'Swing', 120, 2, 5, 3, 2, 5, 4, 5, 2, 2, 4, 4, 5, 1, 5],
    [1, 'Swing', 120, 1, 4, 1, 3, 2, 4, 3, 2, 3, 2, 3, 4, 3, 4],
    [1, 'Swing', 120, 2, 4, 3, 1, 3, 5, 5, 1, 1, 4, 4, 3, 1, 4],
    [1, 'Swing', 120, 3, 5, 3, 2, 5, 5, 4, 2, 2, 5, 5, 5, 2, 5],
    [1, 'Swing', 120, 1, 3, 3, 3, 3, 3, 2, 2, 2, 2, 3, 4, 3, 3],
])

correlacao = perguntas.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlacao, annot=True, cmap='viridis', center=0,
            xticklabels=np.arange(1, 15),  # Rótulos do eixo x começando em 1
            yticklabels=np.arange(1, 15))  # Rótulos do eixo y começando em 1
plt.title('Matriz de Correlação entre Perguntas')
plt.xlabel('Pergunta') # Adicione rótulos aos eixos
plt.ylabel('Pergunta')
plt.show()
