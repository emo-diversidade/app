# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

data = []

# Participantes 1 e 2 (exemplos)
data.extend([
    [1, 'Experimental', 'Swing', 120, 1, 4, 'Alta', 3, 'Média', 2, 4, 5, 4, 6, 'Alta', 1, 'Assertivo', 'Colaborativo', 'Diária', 'Alta', 'Alta', 'Alto', 'Eficaz', 'Monogâmicos', 'Não', 'Flexíveis', 'Baixa', 'Alta', 'Alta', 'Alto'],
    [1, 'Experimental', 'Swing', 120, 2, 5, 'Alta', 4, 'Alta', 1, 5, 5, 5, 12, 'Alta', 2, 'Assertivo', 'Colaborativo', 'Diária', 'Alta', 'Alta', 'Alto', 'Eficaz', 'Monogâmicos', 'Não', 'Flexíveis', 'Baixa', 'Alta', 'Alta', 'Alto'],
    [1, 'Experimental', 'Swing', 120, 3, 5, 'Alta', 5, 'Alta', 1, 5, 5, 5, 18, 'Alta', 2, 'Assertivo', 'Colaborativo', 'Diária', 'Alta', 'Alta', 'Alto', 'Eficaz', 'Monogâmicos', 'Não', 'Flexíveis', 'Baixa', 'Alta', 'Alta', 'Alto'],
    [2, 'Controle', 'Swing', 80, 1, 3, 'Média', 2, 'Baixa', 3, 3, 4, 3, 3, 'Média', 1, 'Passivo', 'Evitativo', 'Semanal', 'Média', 'Baixa', 'Baixo', 'Ineficaz', 'Não-monogâmicos', 'Sim', 'Rígidos', 'Alta', 'Baixa', 'Baixa', 'Baixo'],
    [2, 'Controle', 'Swing', 80, 2, 3, 'Média', 2, 'Baixa', 3, 3, 4, 3, 3, 'Média', 1, 'Passivo', 'Evitativo', 'Semanal', 'Média', 'Baixa', 'Baixo', 'Ineficaz', 'Não-monogâmicos', 'Sim', 'Rígidos', 'Alta', 'Baixa', 'Baixa', 'Baixo']
])

# Visualização: Gráfico de dispersão com cores vibrantes
plt.figure(figsize=(10, 6))
sns.scatterplot(x='compersao', y='satisfacao_relacional', hue='percepcao_stigma', data=df, palette='plasma', s=100, alpha=0.7)
plt.title('Relação entre Compersão e Satisfação Relacional (Colorido por Percepção de Stigma)')
plt.xlabel('Compersão')
plt.ylabel('Satisfação Relacional')
plt.show()


df.to_csv('synthetic_data_with_relationship_history.csv', index=False)
print(df)
# Out:
#      participante         grupo tipo_relacionamento  \
# 0               1  Experimental               Swing
# 1               1  Experimental               Swing
# 2               1  Experimental               Swing
# 3               2      Controle               Swing
# 4               2      Controle               Swing
# ..            ...           ...                 ...
# 114            39  Experimental               Swing
# 115            39  Experimental               Swing
# 116            40      Controle            Poliamor
# 117            40      Controle            Poliamor
# 118            40      Controle            Poliamor
#
#      tempo_relacionamento_meses  momento_medicao  compersao  \
# 0                           120                1          4
# 1                           120                2          5
# 2                           120                3          5
# 3                            80                1          3
# ...
